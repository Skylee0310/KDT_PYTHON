# %% [markdown]
# ### 의사결정나무(DT)
# - IF-ELSE 방식의 질문에 대한 답변으로 문제를 해결하는 알고리즘.
#
# - 피처(특성) 중에서 선택한 기준으로데이터 분할
#
#     * 엔트로피 (불순도) ==> 낮아지는 방향으로 진행.
#         - 예) 배 상자 속에 사과가 섞인 정도
#
#     * 정보이득 : 1-엔트로피 => 높아지는 방향
#
#     * 지니계수 : 불평등수치값 => 낮아지는 방향
# - 단점 : 과대적합이 될 가능성이 높음! 성능이 좋지 않음.
# - 장점 : 전처리의 영향을 받지 않음. / 직관성이 높음. / 피처들 중 주요 피처 확인이 가능.
# - 주의 :
#     * 여기서 주요피처는 데이터 분할을 위한 주요 피처
#     * 100% 데이터의 주요 피처가 아닐 수도 있음.=> 다른 검사 (상관계수, 시각화 등등)와 함께 평가.

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비.

# %%
# 모듈 로딩
import pandas as pd 
import numpy as np

df = pd.read_csv('../data/iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# [2] 학습용 데이터 셋 준비<hr>

# %% [markdown]
# [2-1] 피처와 타겟 분리

# %%
featureDF= df[df.columns[:-1]]
targetSR = df[df.columns[-1]]

# %% [markdown]
# [2-2] 훈련용과 테스트용 데이터셋 분리

# %%
from sklearn.model_selection import train_test_split
Xtrn, Xtst, ytrn, ytst = train_test_split(featureDF, targetSR,
                                          test_size=0.2,
                                          stratify=targetSR)

# %% [markdown]
# [3] 기계학습 진행 <hr>
# - target 데이터 확인 결과 : 3개의 분류.
# - 학습 유형 : 지도 학습 + 분류(classification)
#     * 분류 알고리즘 => knn, logisticRegression, SVM-SVC, Decision TreeClassifier

# %% [markdown]
# [3-1] decision Tree 알고리즘으로 분류

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# 인스턴스 생성
mdl = DecisionTreeClassifier(criterion='entropy')
mdl.fit(Xtrn, ytrn)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
mdl.classes_
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
# 생성된 모델 구조 시각화
from sklearn.tree import export_graphviz # 의사결정 나무 넣는 모듈

print(export_graphviz(mdl, 'iris.text')) #out_file=> 파일로 저장 가능.
print(export_graphviz(mdl, 'iris.png')) #out_file=> 파일로 저장 가능.


# dot 언어로 작성된 내용을 시각화 해주는 모듈
import graphviz as gz 


# DT모델의 시각화 정보를 dot 언어로 작성해서 파일로 저장.
export_graphviz(mdl, out_file='iris_tree.dot', feature_names=mdl.feature_names_in_, class_names=mdl.classes_, filled=True, rounded=True) # filled = True 하면 색 / rounded 하면 사각형 모서리가 둥글어짐.

gz.Source.from_file('iris_tree.dot') # 필드
#gz.Source.from_file('iris.png')
# Out:
# None
# None

# %%
gz.Source.from_file('iris_tree.dot')

# %% [markdown]
# - conda env list ===> 가상환경 리스트
# - conda activate EXAM_ML(가상환경 이름)
# - pip install GraphViz ===> GraphViz 설치
# - python ===> 파이썬 명령어 사용 가능

# %% [markdown]
# [4] 모델 평가<hr>

# %%
train = mdl.score(Xtrn, ytrn)
test = mdl.score(Xtst, ytst)
print(f'[train]:{train}, [test] : {test}')
# Out:
# [train]:1.0, [test] : 0.8333333333333334

# %% [markdown]
# [5] 문제 해결 및 성능 향상 즉, 튜능 <hr>
# - 원인 예상
#     * 데이터셋 부족 => cv
#     * DT의 여러가지 하이퍼파라미터 기본값으로만 사용 => 다양한 값 조절
#
# - 해결 방법
#     * 2개의 원인을 한꺼번에 해결하기 위해서 GridSearchCV

# %%
# 모듈 로딩
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# 모델 적합 조건
# cv => 기본 5, ... 
# DT의 하이퍼파라미터 => max_depth
dtMdl = DecisionTreeClassifier()
n_cv = 5
params = {'criterion':['gini', 'entropy', 'log_loss'], 
         'max_depth':[5, 10, 15],
         'min_samples_split':[2, 4, 6]}

# 하이퍼파라미터 조합된 모델 생성 후 교차검증 데이터셋으로 학습 진행해 주는 인스턴스.
gs = GridSearchCV(dtMdl, param_grid=params, cv=n_cv)

# %%
# 조합된 모델들의 학습 진행
result= gs.fit(Xtrn, ytrn)

# 결과 확인
result
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [5, 10, 15],
#                          'min_samples_split': [2, 4, 6]})

# %%
# 학습 후 저장된 모델 파라미터 확인 
# 교차학습 결과 => 조합된 모델의 개수 만큼 출력.
cv_resultsDF = pd.DataFrame(gs.cv_results_)
cv_resultsDF
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002007      0.000629         0.001415        0.000480
# 1        0.001525      0.000439         0.000816        0.000410
# 2        0.001621      0.000490         0.001321        0.000754
# 3        0.001906      0.000188         0.001002        0.000003
# 4        0.001600      0.000490         0.001412        0.000508
# 5        0.001972      0.000472         0.001440        0.000353
# 6        0.001451      0.000464         0.000604        0.000493
# 7        0.001200      0.000400         0.001049        0.000094
# 8        0.001404      0.000490         0.000795        0.000398
# 9        0.001204      0.000394         0.000796        0.000398
# 10       0.001202      0.000403         0.001000        0.000633
# 11       0.001410      0.000482         0.000809        0.000405
# 12       0.001198      0.000397         0.001002        0.000003
# 13       0.001614      0.000448         0.001412        0.000479
# 14       0.001200      0.000400         0.000598        0.000488
# 15       0.001202      0.000400         0.000813        0.000408
# 16       0.001199      0.000403         0.001020        0.000026
# 17       0.001197      0.000402         0.000602        0.000492
# 18       0.001001      0.000008         0.001113        0.000225
# 19       0.001427      0.000484         0.000400        0.000490
# 20       0.001002      0.000003         0.001020        0.000041
# 21       0.001425      0.000525         0.000601        0.000491
# 22       0.001209      0.000397         0.000607        0.000496
# 23       0.001207      0.000404         0.000701        0.000462
# 24       0.001126      0.000252         0.000805        0.000403
# 25       0.001202      0.000403         0.000997        0.000005
# 26       0.001201      0.000400         0.001201        0.000399
#
#    param_criterion param_max_depth param_min_samples_split  \
# 0             gini               5                       2
# 1             gini               5                       4
# 2             gini               5                       6
# 3             gini              10                       2
# 4             gini              10                       4
# 5             gini              10                       6
# 6             gini              15                       2
# 7             gini              15                       4
# 8             gini              15                       6
# 9          entropy               5                       2
# 10         entropy               5                       4
# 11         entropy               5                       6
# 12         entropy              10                       2
# 13         entropy              10                       4
# 14         entropy              10                       6
# 15         entropy              15                       2
# 16         entropy              15                       4
# 17         entropy              15                       6
# 18        log_loss               5                       2
# 19        log_loss               5                       4
# 20        log_loss               5                       6
# 21        log_loss              10                       2
# 22        log_loss              10                       4
# 23        log_loss              10                       6
# 24        log_loss              15                       2
# 25        log_loss              15                       4
# 26        log_loss              15                       6
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.958333
# 1   {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.958333
# 2   {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.958333
# 3   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.916667
# 4   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.958333
# 5   {'criterion': 'gini', 'max_depth': 10, 'min_sa...           0.958333
# 6   {'criterion': 'gini', 'max_depth': 15, 'min_sa...           0.916667
# 7   {'criterion': 'gini', 'max_depth': 15, 'min_sa...           0.958333
# 8   {'criterion': 'gini', 'max_depth': 15, 'min_sa...           0.958333
# 9   {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.916667
# 10  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.916667
# 11  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.916667
# 12  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.916667
# 13  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.916667
# 14  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.916667
# 15  {'criterion': 'entropy', 'max_depth': 15, 'min...           0.875000
# 16  {'criterion': 'entropy', 'max_depth': 15, 'min...           0.875000
# 17  {'criterion': 'entropy', 'max_depth': 15, 'min...           0.916667
# 18  {'criterion': 'log_loss', 'max_depth': 5, 'min...           0.916667
# 19  {'criterion': 'log_loss', 'max_depth': 5, 'min...           0.875000
# 20  {'criterion': 'log_loss', 'max_depth': 5, 'min...           0.916667
# 21  {'criterion': 'log_loss', 'max_depth': 10, 'mi...           0.916667
# 22  {'criterion': 'log_loss', 'max_depth': 10, 'mi...           0.916667
# 23  {'criterion': 'log_loss', 'max_depth': 10, 'mi...           0.916667
# 24  {'criterion': 'log_loss', 'max_depth': 15, 'mi...           0.875000
# 25  {'criterion': 'log_loss', 'max_depth': 15, 'mi...           0.875000
# 26  {'criterion': 'log_loss', 'max_depth': 15, 'mi...           0.916667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.916667           0.958333                1.0
# 1            0.916667           0.958333                1.0
# 2            0.916667           0.958333                1.0
# 3            0.875000           0.958333                1.0
# 4            0.916667           0.958333                1.0
# 5            0.916667           0.958333                1.0
# 6            0.916667           0.958333                1.0
# 7            0.916667           0.958333                1.0
# 8            0.916667           0.958333                1.0
# 9            0.875000           0.958333                1.0
# 10           0.875000           0.958333                1.0
# 11           0.875000           0.958333                1.0
# 12           0.875000           0.958333                1.0
# 13           0.875000           0.958333                1.0
# 14           0.875000           0.958333                1.0
# 15           0.875000           0.958333                1.0
# 16           0.875000           0.958333                1.0
# 17           0.875000           0.958333                1.0
# 18           0.875000           0.958333                1.0
# 19           0.875000           0.958333                1.0
# 20           0.875000           0.958333                1.0
# 21           0.875000           0.958333                1.0
# 22           0.875000           0.958333                1.0
# 23           0.875000           0.958333                1.0
# 24           0.875000           0.958333                1.0
# 25           0.875000           0.958333                1.0
# 26           0.875000           0.958333                1.0
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.958333         0.958333        0.026352                1
# 1            0.958333         0.958333        0.026352                1
# 2            0.958333         0.958333        0.026352                1
# 3            0.958333         0.941667        0.042492                9
# 4            0.958333         0.958333        0.026352                1
# 5            0.958333         0.958333        0.026352                1
# 6            0.958333         0.950000        0.031180                8
# 7            0.958333         0.958333        0.026352                1
# 8            0.958333         0.958333        0.026352                1
# 9            0.958333         0.941667        0.042492                9
# 10           0.958333         0.941667        0.042492                9
# 11           0.958333         0.941667        0.042492                9
# 12           0.958333         0.941667        0.042492                9
# 13           0.958333         0.941667        0.042492                9
# 14           0.958333         0.941667        0.042492                9
# 15           0.958333         0.933333        0.050000               23
# 16           0.958333         0.933333        0.050000               23
# 17           0.958333         0.941667        0.042492                9
# 18           0.958333         0.941667        0.042492                9
# 19           0.958333         0.933333        0.050000               23
# 20           0.958333         0.941667        0.042492                9
# 21           0.958333         0.941667        0.042492                9
# 22           0.958333         0.941667        0.042492                9
# 23           0.958333         0.941667        0.042492                9
# 24           0.958333         0.933333        0.050000               23
# 25           0.958333         0.933333        0.050000               23
# 26           0.958333         0.941667        0.042492                9

# %%
# 조합된 모델 중 최고의 성능을 내는 하이퍼파라미터 값
gs.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2}

# %%
# 조합된 모델 중 최고의 성능을 내는 모델 인스턴스
my_best_mdl = gs.best_estimator_ # 이렇게 해놓으면 다시 학습시킬 필요없음.

# %%
# 조합된 모델 중 최고의 점수
gs.best_score_
# Out:
# 0.9583333333333334

# %%
# best 점수 기준 ===> tst 점수 기준.

# %% [markdown]
# [6] 학습 및 튜닝 후 모델 저장<hr>
# - 다른 파일에서 활용이 가능한 파일 형태로 저장
# - 웹/앱 원하는 곳에서 활용 가능.
# - scikit-learn에서는 pickle 포맷으로 저장
# - joblib 모듈에 해당 기능 포함되어 있음.

# %%
import joblib
import os

# %%
# 모델 저장
model_dir  = '../model/'
model_filename = model_dir+'iris_df.pkl' #경로를 지정하지 않으면 현재위치에 저장.

# 저장 폴더 존재 여부 확인 후 저장.
if not os.path.exists(model_dir) :
    os.mkdir(model_dir)

# 모델 파일을 지정된 경로에 저장.
joblib.dump(my_best_mdl, model_filename)
# Out:
# ['../model/iris_df.pkl']
