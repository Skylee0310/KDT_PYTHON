# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

file = 'winequality-white.csv'

# %% [markdown]
# 와인의 품질 선별 모델 <hr>
# - 데이터 : wine.csv
# - 피  처 : fixed acidity(고정산도), alcohol(알코올)
# - 타  겟 : quality

# %%
wineDF = pd.read_csv(file, sep = ';') # 구분자 ';'로 설정.
wine_corr = wineDF.corr()
abs(wine_corr['quality']).sort_values(ascending=False).head(3)
# Out:
# quality    1.000000
# alcohol    0.435575
# density    0.307123
# Name: quality, dtype: float64

# %%
# 결측치 확인
# wineDF.isna().sum() # 결측치 없음.

# 이상치 확인
# for col in wineDF.columns:
#     print(wineDF[col].unique)

# 중복값 확인
#wineDF.duplicated().sum()

# %%
# 타겟 고유값 확인 -> 3~9까지
wineDF['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
fx_data = wineDF['density']
al_data = wineDF['alcohol']

# %%
import matplotlib.pyplot as plt
plt.scatter(fx_data, al_data, c = wineDF.quality, alpha=0.6)
plt.show()

# %% [markdown]
# (3) 기계학습을 위한 데이터 준비
# - 피쳐/특성 + 타겟/라벨/클래스
# - 학습용 데이터셋  : 80%
# - 테스트용 데이터셋 : 20%

# %%
wineDF = wineDF.sample(frac = 1.) # 확률 1 = 100% 데이터를 100% 섞는다.
wineDF = wineDF[['quality', 'density', 'alcohol']]
#wineDF = wineDF.reset_index(drop=True)
wineDF
# Out:
#       quality  density  alcohol
# 2255        6  0.99466     10.0
# 4420        6  0.99906      8.8
# 2296        7  0.99460     10.6
# 159         8  0.98940     12.1
# 2146        6  0.99540      9.6
# ...       ...      ...      ...
# 4821        6  0.99176     11.0
# 416         6  0.99270      9.8
# 202         5  0.99730      9.6
# 4673        7  0.99161     11.8
# 2835        6  0.99256     10.5
#
# [4898 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# 피처 및 타겟 준비
featureDF = wineDF[['density', 'alcohol']]
targetSR = wineDF['quality']

X_train, X_test, y_train, y_test = train_test_split(featureDF, targetSR, test_size=0.2)

# %%
print(f"X_train : {X_train.shape}")
print(X_train.head(2))
print()
print(f"y_train : {y_train.shape}")
print(y_train.head(2))
print()
print(f"X_test : {X_test.shape}")
print(X_test.head(2))
print()
print(f"y_test : {y_test.shape}")
print(y_test.head(2))
# Out:
# X_train : (3918, 2)
#       density  alcohol
# 3326  0.99204     10.2
# 2319  0.99096     12.7
#
# y_train : (3918,)
# 3326    5
# 2319    7
# Name: quality, dtype: int64
#
# X_test : (980, 2)
#       density  alcohol
# 4865  0.98822     13.6
# 776   0.99215     11.0
#
# y_test : (980,)
# 4865    6
# 776     6
# Name: quality, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
# 표준 정규분포 스케일링 : 평균 0, 편차 1
# (1) 스케일러 인스턴스 생성
# (2) 데이터에 대한 평균, 표준편차 계산 진행 : fit( ) 메서드
# (3) 데이터에 대한 스케일링 진행 : transform( ) 메서드
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
X_train
# Out:
#       density    alcohol
# 3326  0.99204  10.200000
# 2319  0.99096  12.700000
# 3466  0.99000  12.900000
# 2260  0.99748   9.300000
# 3080  0.99184  10.500000
# ...       ...        ...
# 4380  0.99332  11.066667
# 3715  0.99712   9.100000
# 1908  0.99140  12.500000
# 3493  0.99408  13.000000
# 2009  0.99350  12.200000
#
# [3918 rows x 2 columns]

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaler.mean_
# Out:
# array([ 0.99404241, 10.50855964])

# %%
scaled_X_train = scaler.transform(X_train)
print(scaled_X_train.shape)

scaled_X_test = scaler.transform(X_test)
print(scaled_X_test.shape)
# Out:
# (3918, 2)
# (980, 2)

# %%
## -> 스케일된 데이터의 시각화
#scaled_x_test
plt.scatter(scaled_X_train[:, 0], scaled_X_train[:, 1], c = y_train, alpha=0.3)
# plt.xlabel('alcohol')
# plt.ylabel('densinty')
plt.show()

# %%
# 모델 인스턴스 생성
model = KNeighborsClassifier()

# 학습 진행 => 학습용 데이터로 진행
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
test_scoreList = []
train_scoreList =[]
for k in range(1, 101): # k에는 0이 들어갈 수 없음.
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(scaled_X_train, y_train)
    model.score(scaled_X_test, y_test)
    train_scoreList.append(model.score(scaled_X_train, y_train))
    test_scoreList.append(model.score(scaled_X_test, y_test))

# %%
# 학습 및 테스트 데이터에 대한 점수 확인.
print(f'Train Score : {train_scoreList}')
print(f'Test Score : {test_scoreList}')
# Out:
# Train Score : [0.8810617662072486, 0.7521694742215416, 0.7291985706993364, 0.689382337927514, 0.6643695763144462, 0.6442062276671772, 0.6291475242470649, 0.6112812659520164, 0.5893312914752424, 0.5750382848392037, 0.574527820316488, 0.5627871362940275, 0.5548749361919346, 0.5482388973966309, 0.5467075038284839, 0.5431342521694742, 0.5454313425216948, 0.5464522715671261, 0.5398162327718223, 0.5428790199081164, 0.5416028586013272, 0.5387953037263911, 0.532669729453803, 0.5352220520673813, 0.5352220520673813, 0.5352220520673813, 0.537263910158244, 0.5290964777947933, 0.5262889229198571, 0.531138335885656, 0.5303726391015824, 0.52475752935171, 0.5262889229198571, 0.5324144971924452, 0.5296069423175089, 0.5280755487493619, 0.5303726391015824, 0.5270546197039305, 0.5270546197039305, 0.5262889229198571, 0.5265441551812149, 0.52475752935171, 0.5308831036242981, 0.5288412455334355, 0.5265441551812149, 0.5245022970903522, 0.5209290454313426, 0.5234813680449208, 0.5183767228177641, 0.5183767228177641, 0.5178662582950485, 0.5181214905564063, 0.5193976518631955, 0.5209290454313426, 0.520163348647269, 0.520163348647269, 0.5181214905564063, 0.5196528841245533, 0.5191424196018377, 0.5214395099540582, 0.5158244002041859, 0.5135273098519653, 0.5145482388973966, 0.5119959162838182, 0.5150587034201123, 0.5173557937723329, 0.5148034711587545, 0.512506380806534, 0.510974987238387, 0.5160796324655437, 0.5153139356814701, 0.5163348647269015, 0.514037774374681, 0.514037774374681, 0.5122511485451761, 0.5153139356814701, 0.5137825421133231, 0.5122511485451761, 0.5145482388973966, 0.5119959162838182, 0.5096988259315978, 0.5066360387953037, 0.50944359367024, 0.5135273098519653, 0.5155691679428279, 0.5163348647269015, 0.5188871873404798, 0.5176110260336907, 0.5171005615109749, 0.5204185809086268, 0.5209290454313426, 0.5178662582950485, 0.5150587034201123, 0.5155691679428279, 0.5112302194997448, 0.510974987238387, 0.5112302194997448, 0.5099540581929556, 0.5096988259315978, 0.50944359367024]
# Test Score : [0.563265306122449, 0.5020408163265306, 0.5040816326530613, 0.4989795918367347, 0.536734693877551, 0.5163265306122449, 0.5163265306122449, 0.503061224489796, 0.4816326530612245, 0.49489795918367346, 0.48775510204081635, 0.49081632653061225, 0.49489795918367346, 0.4857142857142857, 0.47551020408163264, 0.4775510204081633, 0.4785714285714286, 0.4775510204081633, 0.4816326530612245, 0.4897959183673469, 0.4826530612244898, 0.47551020408163264, 0.46938775510204084, 0.4683673469387755, 0.4704081632653061, 0.46530612244897956, 0.4683673469387755, 0.46530612244897956, 0.4704081632653061, 0.4806122448979592, 0.4775510204081633, 0.47551020408163264, 0.4704081632653061, 0.4816326530612245, 0.4775510204081633, 0.4826530612244898, 0.49081632653061225, 0.4897959183673469, 0.4928571428571429, 0.4959183673469388, 0.5020408163265306, 0.503061224489796, 0.5010204081632653, 0.503061224489796, 0.5061224489795918, 0.5091836734693878, 0.49795918367346936, 0.5020408163265306, 0.49387755102040815, 0.49387755102040815, 0.4928571428571429, 0.4989795918367347, 0.4959183673469388, 0.4959183673469388, 0.49795918367346936, 0.4969387755102041, 0.503061224489796, 0.49795918367346936, 0.5010204081632653, 0.4989795918367347, 0.49081632653061225, 0.49795918367346936, 0.5020408163265306, 0.5, 0.5, 0.5051020408163265, 0.5061224489795918, 0.5020408163265306, 0.5040816326530613, 0.5102040816326531, 0.5122448979591837, 0.5081632653061224, 0.5071428571428571, 0.5091836734693878, 0.5081632653061224, 0.513265306122449, 0.5112244897959184, 0.5081632653061224, 0.5071428571428571, 0.5071428571428571, 0.5010204081632653, 0.5051020408163265, 0.49489795918367346, 0.5061224489795918, 0.5010204081632653, 0.5020408163265306, 0.49387755102040815, 0.5, 0.4959183673469388, 0.4989795918367347, 0.5, 0.5, 0.5010204081632653, 0.5010204081632653, 0.5010204081632653, 0.5051020408163265, 0.5010204081632653, 0.49795918367346936, 0.503061224489796, 0.5010204081632653]

# %%
# K개수에 따른 학습용/테스트용 점수 시각화
plt.plot(train_scoreList, 'b--', label = 'Train Score')
plt.plot(test_scoreList, 'r-', label = 'Test Score')
plt.title('K&score')
plt.xlabel('K')
plt.ylabel('Score')
plt.legend()
plt.show()

# %%
test_scoreList.index(max(test_scoreList))
# Out:
# 0

# %%
winemodel = KNeighborsClassifier(n_neighbors=1) # n_neighbors = 하이퍼 파라미터
winemodel.fit(scaled_X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
winemodel.score(scaled_X_test, y_test)
# Out:
# 0.563265306122449
