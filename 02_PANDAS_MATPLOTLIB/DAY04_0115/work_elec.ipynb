# %%
import pandas as pd

# %%
file ='../DATA/남북한발전전력량.xlsx'

# %%
elecDF = pd.read_excel(file)

# %%
elecDF
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
for i in range(0, len(
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 elecDF.loc['신재생'] = []
#
# File C:\ProgramData\anaconda3\envs\My_38\lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\anaconda3\envs\My_38\lib\site-packages\pandas\core\indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# -> 1825         self._setitem_with_indexer_missing(indexer, value)
#    1826         return
#    1828 if name == "loc":
#    1829     # must come after setting of missing
#
# ...
