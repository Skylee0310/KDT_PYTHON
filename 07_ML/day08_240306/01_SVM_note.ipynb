# %% [markdown]
# 어떤 문제가 있을 때 문제 해결 방법은 여러가지가 있음.
# - iris 품종 분류
#     - ----> KNN 분류
#     - 데이터 분포
#      - => 선형 : 선형 알고리즘 LogisticRegression()
#      -    - SVM : 분리 선 긋기 (구분선을 기준으로 분류), 높은 인식 성능
#     - 질문 & 답변 => 의사결정나무(decision Tree) => 분류

# %% [markdown]
# SVM -> 서포트 벡터 머신
# - 선형
#     - 구분선을 기분으로 분류.
#
#     - 분류 시 최고의 마진margin을 가지는 구분선을 구하는 분류.
#     - 데이터 사이의 간격 = 마진
#     - => 마진이 넓은 구분선 구하고 싶어함..▶ 클수록 좋은 거라는 듯.
#
#     - 구분선을 그릴 때 구분선에서 같은 거리에 있고 기준이 된 점들...? = 서포트 벡터? 맞나..? 추정 중...
#     -
#     - margin의 기준점이 되는 서포트 벡터 중 어느 한쪽 1 다른 쪽을 -1로 두나봄...
#
#
#     - 3차원이되면 hyper-plane(초평면)

# %% [markdown]
# - 비선형
#     * 공간 상에 구별가능한 공간 상에 구별 가능한 방향으로 매핑시켜 구분 ==> Kernel Tick(Kernel function) : (시각화할 때 커널 밀도 어쩌고....)
# + 커널은 차원...어쩌고...

# %% [markdown]
# - 분류 규칙(decision rule)
# - 일반화 :
#     - margin이 최대가 되는 구분선 설정.
#     - 과적합 문제 해결을 위한 방법
# - 소프트 마진
#     - 하나의 선으로 완벽히 분류 => 과적합 발생 & 마진 최소화
#     - 분류 오류 허용하는 방식 (KDT 5기 교실 성별 분류한다고 했을 때 직선을 그을 수 없음. 그러믄 몇 명 분의 오류는 그냥 무시하쟈 = 소프트 마진.)
#
# ▼ Hard margin과 Soft margin의 예시

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# + 스케일링을 한 이유 : 데이터의 단위가 달라서 -> 왜 데이터의 단위가 다르면 해야하나? 거리를 재야 하기 때문.
# - => 그래서 SVM 때도 해야 됨^^

# %% [markdown]
# - 몇 개까지 봐줄 건지..결정해야됨.
#     + 오차 계산해주는 함수 = 손실함수
#
# - SVM의 c(규제 담당 하이퍼 파라미터) 값.
#     - c 값 ▲ 규제 강화 --- margin 폭 ▼ ==== margin 오류 ▼
#     - c 값 ▼ 규제 약화 --- margin 폭 ▲ ==== margin 오류 ▲ / 과대적합 위험 ▼ (너무 줄이면 과소적합 가능성이 있음.)
#     - => c를 찾아야됨..^^... 근데 넓은 margin을 찾는 게 목표래요...:( 쥬륵
#
# - 오류 값 y =1 이어야 하는데 안된 애들 + y = -1 이어야 하는데 안된 애들 계산하는거 (= 마진 안에 있는 데이터들) ---> 계산에 포함되기는 하나봄....:) 왜애ㅐ.....
# - ==> hinge

# %% [markdown]
# svm.OneclassSVM : 이상치 처리할 때 쓰나봄..?

# %% [markdown]
# #### svc
# - gamma : 구불구불한 정도..? 곡률..? 모지..? 아닌가..?
# - coef0 : poly랑 sigmoid일때만 사용가능.
# - degree : 차원

# %% [markdown]
# - rbf : 가우시안(정규분포...)
# - sigmoid : 0,1로 만드는 거..
# - max_iter : int, default=-1    ---> Hard limit on iterations within solver, or -1 for no limit. max_iter는 멈추지 않아ㅏㅏㅏ....
